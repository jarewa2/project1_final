# %%
# Import libraries 
import pandas as pd
from pathlib import Path

# %%
# read adult_data.csv file into dataframe called adult_df
file = Path("adult_data.csv")
adult_df = pd.read_csv(file)
adult_df.head()
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country  salary
# 0           2174              0               40   United-States   <=50K
# 1              0              0               13   United-States   <=50K
# 2              0              0               40   United-States   <=50K
# 3              0              0               40   United-States   <=50K
# 4              0              0               40            Cuba   <=50K

# %%
# drop the following columns from the original csv fiile: ' fnlwgt', ' capital-gain', ' capital-loss'
adult_df.drop(columns=[' fnlwgt', ' capital-gain', ' capital-loss'], inplace=True)
adult_df.head()
# Out:
#    age          workclass   education   education-num       marital-status  \
# 0   39          State-gov   Bachelors              13        Never-married
# 1   50   Self-emp-not-inc   Bachelors              13   Married-civ-spouse
# 2   38            Private     HS-grad               9             Divorced
# 3   53            Private        11th               7   Married-civ-spouse
# 4   28            Private   Bachelors              13   Married-civ-spouse
#
#            occupation    relationship    race      sex   hours-per-week  \
# 0        Adm-clerical   Not-in-family   White     Male               40
# 1     Exec-managerial         Husband   White     Male               13
# 2   Handlers-cleaners   Not-in-family   White     Male               40
# 3   Handlers-cleaners         Husband   Black     Male               40
# 4      Prof-specialty            Wife   Black   Female               40
#
#    native-country  salary
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3   United-States   <=50K
# 4            Cuba   <=50K

# %%
# Rename the column names
columns = ['Age', 'Workclass', 'Education', 'Education-num', 'Marital-status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Hours-per-week', 'Native-country', 'Salary']
adult_df.columns = columns
adult_df.head()
# Out:
#    Age          Workclass   Education  Education-num       Marital-status  \
# 0   39          State-gov   Bachelors             13        Never-married
# 1   50   Self-emp-not-inc   Bachelors             13   Married-civ-spouse
# 2   38            Private     HS-grad              9             Divorced
# 3   53            Private        11th              7   Married-civ-spouse
# 4   28            Private   Bachelors             13   Married-civ-spouse
#
#            Occupation    Relationship    Race      Sex  Hours-per-week  \
# 0        Adm-clerical   Not-in-family   White     Male              40
# 1     Exec-managerial         Husband   White     Male              13
# 2   Handlers-cleaners   Not-in-family   White     Male              40
# 3   Handlers-cleaners         Husband   Black     Male              40
# 4      Prof-specialty            Wife   Black   Female              40
#
#    Native-country  Salary
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3   United-States   <=50K
# 4            Cuba   <=50K

# %%
# Check if there are any null values and drop them if they exist
adult_df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Education         0
# Education-num     0
# Marital-status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Hours-per-week    0
# Native-country    0
# Salary            0
# dtype: int64

# %%
# Check total number of duplicates 
adult_df.duplicated().sum()
# Out:
# 4243

# %%
# Drop duplicates and check; below code should return '0' if there are no more duplicates
adult_df = adult_df.drop_duplicates().copy()
adult_df.duplicated().sum()
# Out:
# 0

# %%
# Drop applicants that did not fill out parts of their application (drop where there is a ' ?') - add explanation in read me file
for column_name in adult_df:
    if any(adult_df[(adult_df[column_name] == ' ?')].index) != []:
        applicants = adult_df[(adult_df[column_name] == ' ?')].index
        adult_df.drop(applicants, inplace = True)

# The total number of unique applicants who have filled out the application completely can be found by running the code below
adult_df.count()
# Out:
# C:\Users\arewa\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Age               26142
# Workclass         26142
# Education         26142
# Education-num     26142
# Marital-status    26142
# Occupation        26142
# Relationship      26142
# Race              26142
# Sex               26142
# Hours-per-week    26142
# Native-country    26142
# Salary            26142
# dtype: int64

# %%
# Clean identified fields that have a " " before the entry
for column_name in adult_df:
    if adult_df.dtypes[column_name] == object:
        adult_df[column_name] = adult_df[column_name].str.replace(" ", "")
# Out:
#    Age         Workclass  Education  Education-num      Marital-status  \
# 0   39         State-gov  Bachelors             13       Never-married
# 1   50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2   38           Private    HS-grad              9            Divorced
# 3   53           Private       11th              7  Married-civ-spouse
# 4   28           Private  Bachelors             13  Married-civ-spouse
#
#           Occupation   Relationship   Race     Sex  Hours-per-week  \
# 0       Adm-clerical  Not-in-family  White    Male              40
# 1    Exec-managerial        Husband  White    Male              13
# 2  Handlers-cleaners  Not-in-family  White    Male              40
# 3  Handlers-cleaners        Husband  Black    Male              40
# 4     Prof-specialty           Wife  Black  Female              40
#
#   Native-country Salary
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States  <=50K
# 3  United-States  <=50K
# 4           Cuba  <=50K

# %%
# create a new dataframe by sorting applicants by 'Age'
adult_age_df = adult_df.sort_values('Age')
adult_age_df
# Out:
#        Age  Workclass     Education  Education-num      Marital-status  \
# 26807   17    Private           9th              5       Never-married
# 21196   17    Private          10th              6       Never-married
# 31131   17    Private          11th              7       Never-married
# 26793   17    Private          10th              6       Never-married
# 14785   17    Private          11th              7       Never-married
# ...    ...        ...           ...            ...                 ...
# 18725   90  Local-gov       HS-grad              9  Married-civ-spouse
# 4070    90    Private          11th              7       Never-married
# 6624    90    Private          11th              7  Married-civ-spouse
# 2303    90    Private  Some-college             10       Never-married
# 22220   90    Private     Bachelors             13       Never-married
#
#               Occupation    Relationship                Race     Sex  \
# 26807  Machine-op-inspct       Own-child               White    Male
# 21196      Other-service       Own-child               White  Female
# 31131              Sales       Own-child               White    Male
# 26793              Sales  Other-relative               White    Male
# 14785  Handlers-cleaners       Own-child               White    Male
# ...                  ...             ...                 ...     ...
# 18725      Other-service         Husband               White    Male
# 4070   Handlers-cleaners       Own-child               White    Male
# 6624        Craft-repair         Husband               White    Male
# 2303       Other-service   Not-in-family  Asian-Pac-Islander    Male
# 22220     Prof-specialty   Not-in-family  Asian-Pac-Islander    Male
#
#        Hours-per-week Native-country Salary
# 26807              20  United-States  <=50K
# 21196              14  United-States  <=50K
# 31131               5  United-States  <=50K
# 26793              30  United-States  <=50K
# 14785              15  United-States  <=50K
# ...               ...            ...    ...
# 18725              40  United-States  <=50K
# 4070               40  United-States  <=50K
# 6624               40  United-States  <=50K
# 2303               35  United-States  <=50K
# 22220              40  United-States  <=50K
#
# [26142 rows x 12 columns]

# %%
# Create a new dataframe by sorting applicants by 'Education-num'
adult_edu_num_df = adult_df.sort_values('Education-num')
adult_edu_num_df
# Out:
#        Age    Workclass  Education  Education-num         Marital-status  \
# 2884    71      Private  Preschool              1                Widowed
# 21370   61      Private  Preschool              1  Married-spouse-absent
# 32432   36      Private  Preschool              1               Divorced
# 7894    26      Private  Preschool              1  Married-spouse-absent
# 6864    54      Private  Preschool              1     Married-civ-spouse
# ...    ...          ...        ...            ...                    ...
# 4805    51  Federal-gov  Doctorate             16          Never-married
# 25831   31      Private  Doctorate             16     Married-civ-spouse
# 28082   33    State-gov  Doctorate             16     Married-civ-spouse
# 21430   52    Local-gov  Doctorate             16     Married-civ-spouse
# 24826   39    State-gov  Doctorate             16               Divorced
#
#               Occupation   Relationship                Race     Sex  \
# 2884        Craft-repair      Unmarried               Black    Male
# 21370      Other-service  Not-in-family  Asian-Pac-Islander    Male
# 32432      Other-service  Not-in-family               Other    Male
# 7894   Machine-op-inspct  Not-in-family               White    Male
# 6864     Farming-fishing        Husband               White    Male
# ...                  ...            ...                 ...     ...
# 4805      Prof-specialty  Not-in-family               White  Female
# 25831     Prof-specialty        Husband               White    Male
# 28082     Prof-specialty        Husband               White    Male
# 21430    Exec-managerial        Husband               White    Male
# 24826     Prof-specialty  Not-in-family               White  Female
#
#        Hours-per-week Native-country Salary
# 2884               10  United-States  <=50K
# 21370              40          China  <=50K
# 32432              72         Mexico  <=50K
# 7894               40         Mexico  <=50K
# 6864               60  United-States  <=50K
# ...               ...            ...    ...
# 4805               70  United-States   >50K
# 25831              99  United-States   >50K
# 28082              50  United-States   >50K
# 21430              40  United-States   >50K
# 24826              40  United-States   >50K
#
# [26142 rows x 12 columns]

# %%
# Create a new dataframe by sorting applicants by 'Hours-per-week'
adult_hpw_df = adult_df.sort_values('Hours-per-week')
adult_hpw_df
# Out:
#        Age         Workclass     Education  Education-num      Marital-status  \
# 11451   27           Private       HS-grad              9       Never-married
# 25078   74           Private          10th              6            Divorced
# 19750   23           Private       HS-grad              9       Never-married
# 24284   57  Self-emp-not-inc       HS-grad              9  Married-civ-spouse
# 22960   21           Private       HS-grad              9       Never-married
# ...    ...               ...           ...            ...                 ...
# 12788   24         State-gov     Doctorate             16       Never-married
# 12625   51           Private     Doctorate             16  Married-civ-spouse
# 23830   45  Self-emp-not-inc  Some-college             10  Married-civ-spouse
# 15356   90           Private       HS-grad              9             Widowed
# 16604   73  Self-emp-not-inc       7th-8th              4  Married-civ-spouse
#
#               Occupation    Relationship                Race     Sex  \
# 11451  Machine-op-inspct  Other-relative               White    Male
# 25078      Other-service   Not-in-family               White  Female
# 19750       Craft-repair       Own-child  Asian-Pac-Islander    Male
# 24284    Exec-managerial         Husband               White    Male
# 22960  Machine-op-inspct       Own-child               Black    Male
# ...                  ...             ...                 ...     ...
# 12788     Prof-specialty   Not-in-family               White  Female
# 12625     Prof-specialty         Husband  Asian-Pac-Islander    Male
# 23830      Other-service            Wife               White  Female
# 15356   Transport-moving       Unmarried               White    Male
# 16604    Farming-fishing         Husband               White    Male
#
#        Hours-per-week Native-country Salary
# 11451               1  United-States  <=50K
# 25078               1  United-States  <=50K
# 19750               1        Vietnam  <=50K
# 24284               1  United-States  <=50K
# 22960               1  United-States  <=50K
# ...               ...            ...    ...
# 12788              99        England  <=50K
# 12625              99          South  <=50K
# 23830              99  United-States  <=50K
# 15356              99  United-States  <=50K
# 16604              99  United-States   >50K
#
# [26142 rows x 12 columns]

# %%
# Save cleaned adult_df dataframe to a new csv called "applicants"
adult_df.to_csv('applicants.csv', index=False)
